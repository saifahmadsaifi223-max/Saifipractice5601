# %%
** euclidean distance**
-

# %% [markdown]
# <img alt="Euclidean Distance for finding Similarity – Machine Learning For Analytics" id="dimg_HzWYas2gKauRseMPs9LTEQ_48" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyfcDvNSG--uBqyP3knP1tE3PDILAwR7Q0JajyvRPHxA&amp;s=10" data-csiid="HzWYas2gKauRseMPs9LTEQ_14" data-atf="1">

# %%
from numpy.linalg import norm

# %% [markdown]
# # formula norm
# <img src="https://cdn.builtin.com/cdn-cgi/image/f=auto/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/vector-norms-12.png" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 810px; width: 485px; height: 236px; margin: 0px;" alt="Vector Norms: A Quick Guide | Built In" jsname="kn3ccd">

# %%
l=[3,4]
norm(l)
# Out:
# np.float64(5.0)

# %%
import numpy as np
x=[10,20]
y=[30,40]
arr1=np.array(x)
arr2=np.array(y)
# euclidean distance formulae
np.sqrt(np.sum(np.square(arr1-arr2)))
# Out:
# np.float64(28.284271247461902)

# %%
x=[10,20]
y=[30,40]
arr1=np.array(x)
arr2=np.array(y)
norm(arr1-arr2)
# Out:
# np.float64(28.284271247461902)

# %%
l=[3,4]
arr2=norm(l)
print(arr2)
np.sqrt(np.sum(np.square(l)))
# Out:
# 5.0
# np.float64(5.0)

# %% [markdown]
# ** lets represent a vector**

# %% [markdown]
# -for drawing the graph we need matplotlib

# %%
a=[1,1]
b=[1,2]

# %%
import matplotlib.pyplot as plt
matplotlib.__version__
# Out:
# '3.11.0'

# %%
plt.arrow(0,0,1,2,color="blue",head_width=0.1)
plt.arrow(0,0,1,1,color="red",head_width=0.1)
plt.xlim(0,3)
plt.ylim(0,3)
plt.show()

# %%
x=[10,20]
y=[20,40]
arrx=np.array(x)
arry=np.array(y)

# here dot product means this 
# nr=np.sum(arrx*arry)
nr=np.dot(arrx,arry)
dnr=norm(arrx)*norm(arry)

csv=nr/dnr

# %%
import math

# %%
math.cos
math.acos  # this will give the answer in radians so we have to convert them into radians
# Out:
# 8.537736462515939e-07

# %%
math.degrees(math.acos(csv))
# Out:
# 8.537736462515939e-07

# %%
math.degrees(math.acos(0))
# Out:
# 90.0

# %% [markdown]
# - we will take one model
# - we will take a list of sentencases
# - we will convert those sentece into vector
# - we will take one question
# - we will convert that qn into vector
# - we will aplly cosine similarity between qv with input vector
# - it should pick correct answer

# %% [markdown]
# ** transformer package**

# %%
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#
# ModuleNotFoundError: No module named 'sentence_transformers'
