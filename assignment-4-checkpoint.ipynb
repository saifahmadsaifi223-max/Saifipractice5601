# %%
""" Ramesh’s basic salary is input through the keyboard. His dearness allowance is 
    40% of basic salary, and house rent allowance is 20% of basic salary.
    Write a program to calculate his gross salary. """
# Gross Salary= Basic Salary+HRA+other allowance
b_sal=eval(input("enter your basic salary"))
d_allowance= 0.4*b_sal
r_allowance= 0.2*b_sal
gross_salary= b_sal + d_allowance + r_allowance 
print(gross_salary)
# Out:
# enter your basic salary 20000
# 32000.0

# %%
""" The distance between two cities (in km.) is input through the keyboard.
    Write a program to convert and print this distance in meters, feet, 
    inches and centimeters. """

distance=eval(input("enter the distance between two cities in km: "))
print(f"The {distance}km is:{distance*1000}meter")
print(f"The {distance}km is:{distance*1000*3.2}feet")
print(f"The {distance}km is:{distance*1000*39.7}inches")
print(f"The {distance}km is:{distance*1000*100}centimeters")
# Out:
# enter the distance between two cities in km:  1
# The 1km is:1000meter
# The 1km is:3200.0feet
# The 1km is:39700.0inches
# The 1km is:100000centimeters

# %%
""" If the marks obtained by a student in five different subjects are input through the keyboard,
find out the aggregate marks and percentage marks obtained by the student. 
Assume that the maximum marks that can be obtained by a student in each subject is 100."""

eng =eval(input("enter the marks of the student obtained in enlish out of 100: "))
urdu=eval(input("enter the marks of the student obtained in urdu out of 100: "))
hindi=eval(input("enter the marks of the student obtained in hindi out of 100: "))
maths=eval(input("enter the marks of the student obtained in maths out of 100: "))
chem=eval(input("enter the marks of the student obtained in science out of 100: "))

aggregate_marks=eng+urdu+hindi+maths+chem

percetage_marks= aggregate_marks*0.2

print(f"aggregate marks={aggregate_marks} \n Totalmarks(in%) = {percetage_marks}%")
# Out:
# enter the marks of the student obtained in enlish out of 100:  50
# enter the marks of the student obtained in urdu out of 100:  50
# enter the marks of the student obtained in hindi out of 100:  50
# enter the marks of the student obtained in maths out of 100:  50
# enter the marks of the student obtained in science out of 100:  50
# aggregate marks=250
#  Totalmarks(in%) = 50.0%

# %%
""" Temperature of a city in Fahrenheit degrees is input through the keyboard. 
    Write a program to convert this temperature into Centigrade degrees       """


temp=eval(input("enter the temperature of your cite in fahrenheit"))
temp_celcius= (temp-32)*5/9
print(temp_celcius)
# Out:
# enter the temperature of your cite in fahrenheit 100
# 37.77777777777778

# %%
""" the length & breadth of a rectangle and radius of a circle are input through the keyboard. 
    Write a program to calculate the area & perimeter of the rectangle, \
    and the area & circumference of the circle      """

l=eval(input("enter the length"))
b=eval(input("enter the breadth"))
r=eval(input("enter the raius of the circle"))


print(f"Area of rectangle:{l*b} \n permeter of rectange is:{2*(l+b)}")
print(f"The area of circle is:{3.14*r*r} \n perimeter of circle:{2*3.14*r}")
# Out:
# enter the length 3
# enter the breadth 3
# enter the raius of the circle 3
# Area of rectangle:9
#  permeter of rectange is:12
# The area of circle is:28.259999999999998
#  perimeter of circle:18.84

# %%
"""Two numbers are input through the keyboard into two locations C and D.
   Write a program to interchange the contents of C and D. """

# %%
c=eval(input("enter the number1 in c:"))
d=eval(input("enter the number2 in d:"))

c,d=d,c
print(f"after exchange the number in {c,d}:")
# Out:
# enter the number1 in c: 4
# enter the number2 in d: 5
# after exchange the number in (5, 4):

# %%
# If a five-digit number is input through the keyboard, write a program to reverse the number. 

f_num=input("enter the five digit number")
reverse=f_num[::-1]
print(reverse)
# Out:
# enter the five digit number 12345
# 54321

# %%
# If a four-digit number is input through the keyboard,
# write a program to obtain the sum of the first and last digit of this number.

f_num=input("enter the fourdigit number")

a=f_num[0]
b=f_num[3]
print(f"the sum of first and last number:{int(a)+int(b)}")
# Out:
# enter the fourdigit number 1234
# the sum of first and last number:5

# %%
""" In a town, The percentage of men is 52. The percentage of total literacy is 48. 
   If total percentage of literate men is 35 of the total population, 
   write a program to find the total number of illiterate men and women if the population of the town is 80,000."""

t_population=80000
per_men=52
t_men=(800*52)
t_fem= 80000-t_men
print(f"total men: {t_men}")
print(f"total female: {t_fem}")

lit_pop=(0.48*80000)
print(f"total literate population:{lit_pop}")

lit_men=80000*0.35
print(f"literate men:{lit_men}")  #lit men

lit_fem=(lit_pop-lit_men)
print(f"literate female: {lit_fem}") #lit fem

ilit_pop=(80000-lit_pop)
print(f"total illeterate population: {ilit_pop}") #total ilitirate pop


ilit_fem=(t_fem-lit_fem)
print(f"total illeterate female:{ilit_fem}")
ilit_men=(t_men-lit_men)
print(f"total illeterate men: {ilit_men}")
# Out:
# total men: 41600
# total female: 38400
# total literate population:38400.0
# literate men:28000.0
# literate female: 10400.0
# total illeterate population: 41600.0
# total illeterate female:28000.0
# total illeterate men: 13600.0

# %%
""" A cashier has currency notes of denominations 10, 50 and 100. 
   If the amount to be withdrawn is input through the keyboard in hundreds, 
   find the total number of currency notes of each denomination the cashier 
   will have to give to the withdrawer."""



amount = int(input("Enter amount to withdraw: "))

n_100 = amount // 100
remaining = amount % 100

n_50 = remaining // 50
remaining = remaining % 50

n_10 = remaining // 10

print(f"₹100 notes: {n_100}")
print(f"₹50 notes: {n_50}")
print(f"₹10 notes: {n_10}")
# Out:
# ₹100 notes: 0
# ₹50 notes: 0
# ₹10 notes: 4

# %%
def fac(n):
    if n==1:
        return 1
    return n*(fac(n-1))
n=int(input("enter the number"))
fac(n)
# Out:
# 120
