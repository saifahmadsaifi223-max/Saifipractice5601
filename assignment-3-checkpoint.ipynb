# %% [raw]
# """ Execute each and every package and methods
#
# 1. random
#  randint
# random
# choice
# sample
# seed
#
# 2.Math
# sqrt
# pow
# pi
# e
#
# 3.time
# sleep
# time
#
# 4.keywords
# kwlist
#
# 5.os
# getcwd
# makdirs
#
# 6.Date
#   today date
#
# 7. numpy
#     min
#     max
#     sum
#     square """

# %%
import random
random.randint(10,13)
random.random()
a="hii,my self saifi"
random.choice(a) # it gives me the random element from the string i created in variable a
random.sample(['a','f'],k=5,counts=[3,3])
print(f"{random.seed(a="saifi",version=2)}")
# Out:
# None

# %%
import math
math.pi
math.pow(2,3) # it will give the a^b here, must be real number a and b
math.sqrt(3)   #it will the square root of the 
math.e
# Out:
# 2.718281828459045

# %%
import time
time.sleep(1.2)
time.time()     # this will give the time in sec from the epoch (epoch is time from jan1 1970 this time followed by 
                # cumputer for managing evnet better by bypasiing the everytime zone)
# Out:
# 1786712815.2277122

# %%
import keyword
dir(keyword)

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import datetime
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  'UTC',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
datetime.date.today() #this gives the present date
# Out:
# datetime.date(2026, 8, 14)

# %%
datetime.datetime.now() #this will gives us eveything tofaye date time sec hour
# Out:
# datetime.datetime(2026, 8, 14, 18, 52, 39, 496882)

# %%
datetime.datetime.now().time() # this gives current time
# Out:
# datetime.time(18, 53, 44, 730052)

# %%
import numpy
dir(numpy)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
list=[13,34,234,234,234,2552,24,1]
numpy.min(list) # gives the minimum number presnet in a list
# Out:
# np.int64(1)

# %%
numpy.max(list) #max number present in a list
# Out:
# np.int64(2552)

# %%
numpy.sum(list) #sum of all number present in a list
# Out:
# np.int64(3326)

# %%
numpy.square(list) #square of everynumber in a list retuen in array
# Out:
# array([    169,    1156,   54756,   54756,   54756, 6512704,     576,
#              1])

# %%
numpy.sqrt(list) # sqauare root of every numbe present in list
# Out:
# array([ 3.60555128,  5.83095189, 15.29705854, 15.29705854, 15.29705854,
#        50.51732376,  4.89897949,  1.        ])
